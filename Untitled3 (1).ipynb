# %%
import pandas as pd

# %% [markdown]
# Pandas was imported in order to run the County Health Data set, which will furter disected to look at the homicide rate and health care costs in NC

# %%
dd=pd.read_csv("CountyHealthData.csv")

# %% [markdown]
# The County Health Dataset was imported as a csv file using the instructions from the python notebook, so Pandas can run te data and it be used as a data set

# %%
dd["State"]
# Out:
# 0       AK
# 1       AK
# 2       AK
# 3       AK
# 4       AK
#         ..
# 6104    WY
# 6105    WY
# 6106    WY
# 6107    WY
# 6108    WY
# Name: State, Length: 6109, dtype: object

# %% [markdown]
# State was used, as NC is the focus of the data set and state has to used prior to further specification

# %%
dd[dd["State"]=="NC"]
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# ...

# %% [markdown]
# This contains all of the County Health Data from the state of NC, and was imported to narrow down to two points of interest

# %%
NC_Subset=dd[dd["State"] == "NC"].copy()

# %% [markdown]
# This was created to using the instructions in the python notebook to narrow down my data set areas of focus and to create a csv file of it

# %%
NC_Subset
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# ...

# %% [markdown]
# This shows all of the Health Data from NC across the varoius regions and regions. I will focus on the homicide rate and health care costs.

# %%
NC_Subset.to_csv("NC_Subset.csv", index=False)

# %% [markdown]
# This was created to using the instructions in the python notebook to narrow down my data set areas of focus and to create a csv file of it.

# %%
dd[["State","Health care costs", "Homicide rate",]]
# Out:
#      State  Health care costs  Homicide rate
# 0       AK             3791.0            NaN
# 1       AK             4837.0            NaN
# 2       AK             6588.0           6.29
# 3       AK             6582.0           5.60
# 4       AK             5860.0          12.77
# ...    ...                ...            ...
# 6104    WY             7600.0            NaN
# 6105    WY             8202.0            NaN
# 6106    WY             7940.0            NaN
# 6107    WY             6906.0            NaN
# 6108    WY             7238.0            NaN
#
# [6109 rows x 3 columns]

# %% [markdown]
# This Data set shows the health care costs and homicide rate that I will focus on
